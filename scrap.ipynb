# %%
# !pip install -U snscrape
# Out:
# ...
#      |████████████████████████████████| 71 kB 4.2 MB/s eta 0:00:011
# ...
#   Attempting uninstall: snscrape
#     Found existing installation: snscrape 0.5.0.20230113
#     Uninstalling snscrape-0.5.0.20230113:
#       Successfully uninstalled snscrape-0.5.0.20230113
# ...

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# %%
'''
API key: zXJGDExRwg74BI0avfNQl8E3H
API key secret: UmIcFlCzWkyVaTDMXoYIzZtrRQjeVIRjHfemgQA00SHVp0kw6e
Bearer token: AAAAAAAAAAAAAAAAAAAAAJP0lwEAAAAANMZh8%2BiOHdz%2FqAPp9sutlLU0z2A%3DPkHBt6vilR7OlJ7GxtPmr48e6uUQK0UxrT8gSnb2KBJbKZsfkN
'''
# Out:
# '\nAPI key: zXJGDExRwg74BI0avfNQl8E3H\nAPI key secret: UmIcFlCzWkyVaTDMXoYIzZtrRQjeVIRjHfemgQA00SHVp0kw6e\nBearer token: AAAAAAAAAAAAAAAAAAAAAJP0lwEAAAAANMZh8%2BiOHdz%2FqAPp9sutlLU0z2A%3DPkHBt6vilR7OlJ7GxtPmr48e6uUQK0UxrT8gSnb2KBJbKZsfkN\n'

# %%
# Setting variables to be used below
maxTweets = 6000
# Creating list to append tweet data to
tweets_list2 = []
# Using TwitterSearchScraper to scrape data and append tweets to list
# for i,tweet in enumerate(sntwitter.TwitterSearchScraper('balen since:2022-01-01 until:2023-02-28').get_items()):
# for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:elonmusk since:2022-01-01 until:2023-02-28').get_items()):
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('chatgpt since:2022-01-01 until:2023-03-13').get_items()):
    print(i)
    if i>maxTweets:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.username, tweet.likeCount])

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Like Count'])
tweets_df2.to_csv("chatgpt_tweet_new.csv", index = False)

# %%
tweets_df2.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2023-03-12 23:59:59+00:00  1635068150483156993
# 1 2023-03-12 23:59:59+00:00  1635068148809621504
# 2 2023-03-12 23:59:52+00:00  1635068120623882241
# 3 2023-03-12 23:59:51+00:00  1635068117482356737
# 4 2023-03-12 23:59:48+00:00  1635068101980213248
#
#                                                 Text      Username  Like Count
# 0  米山議員の行動原理は「強烈な自己顕示欲」ですよ。それをベースに、パターンに応じて周囲に賞賛さ...         k0ii6           0
# 1  ChatGPTでSQLを自動生成する「SQL AI アシスタント」、DB管理画面のローコード...    Nautilus99           0
# 2  @criprights Chatgpt's information load is up t...      FreoPope           0
# 3                Hmm chat GPT is actually very valid    NyamekyeOA           1
# 4  @BllrsMer @leonardovalente @LeoPiccioli Claro ...  Brancamonteh           0

# %%
tweets_df2.sample(n=20)
# Out:
#                       Datetime             Tweet Id  \
# 4482 2023-03-12 19:16:24+00:00  1634996784786456576
# 1132 2023-03-12 22:43:52+00:00  1635048992156573698
# 44   2023-03-12 23:57:18+00:00  1635067471739879424
# 1865 2023-03-12 22:00:43+00:00  1635038136043556866
# 1200 2023-03-12 22:40:01+00:00  1635048025449185280
# 1232 2023-03-12 22:38:11+00:00  1635047562125381632
# 180  2023-03-12 23:48:43+00:00  1635065312847749121
# 1594 2023-03-12 22:15:59+00:00  1635041976931467265
# 1484 2023-03-12 22:22:46+00:00  1635043685657083904
# 4127 2023-03-12 19:40:54+00:00  1635002946764013569
# 4306 2023-03-12 19:28:20+00:00  1634999784984674304
# 4134 2023-03-12 19:40:30+00:00  1635002845950013440
# 41   2023-03-12 23:57:30+00:00  1635067522096730113
# 2155 2023-03-12 21:41:06+00:00  1635033199394058241
# 1002 2023-03-12 22:52:21+00:00  1635051129456439298
# 1253 2023-03-12 22:36:49+00:00  1635047219870179329
# 43   2023-03-12 23:57:21+00:00  1635067486424158209
# ...
